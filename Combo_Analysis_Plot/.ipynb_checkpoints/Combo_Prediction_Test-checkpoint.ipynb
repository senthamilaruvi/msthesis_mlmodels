# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import combo
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from mpl_toolkits.mplot3d import Axes3D

# %%
#Loading the Data
#Import Data
os.chdir('E:\Academics\Research\Data\Experimental data\Compression_test\Analysis\Input\As_Built')
Master_Data = pd.read_csv('Input_Data.csv').dropna()

# %%
# Input and output columns in Dataframe
Input = ['X','Y','Theta','Phi']
Properties = ['Yield','Modulus','Ultimate','Ductility']
Output = Properties[0]

# %%
# Normalization of data
full = []
full.extend(Input)
full.extend(Properties)
Parsed_Data = Master_Data[full]
Parsed_Data = Parsed_Data[Parsed_Data['Phi']==45]

# %%
IO = ['X','Y','Theta',Output]
Parsed_Data = Parsed_Data[IO]

# %%
c = Parsed_Data['Y'].max()
Y_transform = []
for a in Parsed_Data['Y']:
    if a <= c/2:
        b = a - (c/4)
    elif a > c/2:
        b = (3*c/4) - a
    Y_transform.append(b)

# %%
Y_transform_norm = Y_transform/(np.max(Y_transform))

# %%
Normalized_Data = (Parsed_Data-Parsed_Data.min())/(Parsed_Data.max()-Parsed_Data.min())

# %%
Normalized_Data['Y_transform']= Y_transform_norm

# %%
new_input = ['Y_transform','Theta']

# %%
# Name Input and target values
X = Normalized_Data[new_input1].values
y = Normalized_Data[Output].values

# %%
#Fitting the Data
cov = combo.gp.cov.gauss(X.shape[1], ard = False)
mean = combo.gp.mean.zero()
lik = combo.gp.lik.gauss()
gp = combo.gp.model(lik = lik,mean = mean, cov = cov)
config = combo.misc.set_config()
np.random.seed(1000)

# %%
#Splitting into training and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
index = np.random.permutation(xrange(X_train.shape[0]))
index
# Out:
# array([31, 32,  8, 26, 34,  6,  3, 43,  2, 22, 38, 36, 15, 16, 17, 42,  4,
#        37, 19, 11, 12,  5, 14, 10, 21, 29, 13, 33, 35, 18, 24,  9, 40, 20,
#        27, 39, 25, 41,  1, 28, 30,  0,  7, 23])

# %%
X_train = X_train[index,:]
y_train = y_train[index]

# %%
gp.fit(X_train, y_train, config)
gp.prepare(X_train, y_train)
# Out:
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 686.203885
# 50 -th epoch marginal likelihood 599.286655776
# 100 -th epoch marginal likelihood 525.574583314
# 150 -th epoch marginal likelihood 461.208444389
# 200 -th epoch marginal likelihood 402.867813232
# 250 -th epoch marginal likelihood 348.035476103
# 300 -th epoch marginal likelihood 295.299909755
# 350 -th epoch marginal likelihood 245.368254531
# 400 -th epoch marginal likelihood 201.258447577
# 450 -th epoch marginal likelihood 165.681811868
# 500 -th epoch marginal likelihood 138.742832383
# Done

# %%
# Predict mean and Standard deviation
y_predicted_mean =  gp.get_post_fmean(X_train, X_test)
y_predicted_fcov = gp.get_post_fcov(X_train, X_test)
y_predicted_sigma = []

for i in range(X_test.shape[0]):
    y_predicted_sigma.append(np.sqrt(y_predicted_fcov[i]))

# %%
rge = Parsed_Data[Output].max()-Parsed_Data[Output].min()
mv = Parsed_Data[Output].min()

# %%
std = np.array(y_predicted_sigma)

# %%
std = std*(rge)

# %%
y_predicted_mean = y_predicted_mean*(rge)+ mv

# %%
y_test = y_test*rge +mv

# %%
fig2 = plt.figure(figsize=(16,9))
ax = fig2.add_subplot(111)
ax.plot(y_test,y_predicted_mean,'.',markersize = 20)
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')
xlim = ax.get_xlim()
ylim = ax.get_ylim()
ax.plot(y_test, y_test, 'k--')
# Out:
# <img src="data:image/png;base64,...">

# %%
r2_score(y_test,y_predicted_mean )
# Out:
# -4.3350256583861908

# %%
fig = plt.figure()
ax = Axes3D(fig)



ax.bar(Parsed_Data['X'], Parsed_Data[Output],Parsed_Data['Y'], zdir = 'y' )
plt.show()
# Out:
# <img src="data:image/png;base64,...">
