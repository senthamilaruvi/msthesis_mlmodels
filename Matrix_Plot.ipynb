# %%
# %matplotlib inline

# %%
import os
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
#Import Data
os.chdir('E:\Academics\Research\Data\Experimental data\Compression_test\Results\As_Built')
Master_Data = pd.read_csv('Data_As_Built_New.csv').dropna()
list(Master_Data)
# Out:
# ['Name',
#  'Number',
#  'X',
#  'Y',
#  'Theta',
#  'Phi',
#  'Porosity_Fraction',
#  'Max_Pore_Diameter',
#  'Mean_Pore_Diameter',
#  'Median_Pore_Diameter',
#  'Median_Pore_Spacing',
#  'Yield',
#  'Modulus']

# %%
Input = ['X','Y','Theta','Phi','Max_Pore_Diameter','Porosity_Fraction']
Properties = ['Yield','Modulus']
Output = Properties[0]

# %%
# Extracting required data from master data
full = []
full.extend(Input)
full.extend(Properties)
Parsed_Data = Master_Data[full]

# %%
Parsed_Data.head(5)
# Out:
#        X      Y  Theta  Phi  Max_Pore_Diameter  Porosity_Fraction  Yield  \
# 0  242.5   22.5     90   45              80.32           0.001433    645
# 1  242.5  224.5     90   90              89.86           0.003579    745
# 2  233.5   32.0      0    0              61.80           0.001537    451
# 4  233.5   82.5      0   45              72.22           0.002596    733
# 6  233.5  224.5     90   90              89.00           0.003240    419
#
#    Modulus
# 0      111
# 1      133
# 2       80
# 4      199
# 6      157

# %%
plt.rc('image', aspect='equal')
plt.rc('figure', figsize=(16, 16))
axis = pd.tools.plotting.scatter_matrix(Parsed_Data,alpha = 0.2)
plt.tight_layout()
